# %%
# Module 1: Content Performance Tracker (Data Collection)

'''This notebook documents the automated data extraction process used
to collect social media content performance metrics using the
YouTube Data API v3.

The collected raw data serves as the foundation for all subsequent
modules including sentiment analysis, virality prediction,
A/B testing, and trend forecasting.'''
# Out:
# 'This notebook documents the automated data extraction process used\nto collect social media content performance metrics using the\nYouTube Data API v3.\n\nThe collected raw data serves as the foundation for all subsequent\nmodules including sentiment analysis, virality prediction,\nA/B testing, and trend forecasting.'

# %%
import pandas as pd
import os

# %%
DATA_PATH = "../data/raw/raw_social_data.csv"

# Check if file exists
if not os.path.exists(DATA_PATH):
    raise FileNotFoundError("Raw data file not found. Please run fetch_data.py first.")

df = pd.read_csv(DATA_PATH)

df.head()
# Out:
#       video_id                                              title     views  \
# 0  WmW5E1bfuOg  Best Camera Phone देख कर Tourist हुए खुश  🤩#sh...    753007
# 1  I3e7Bh5a520            ₹2.5 Lakh AI Dog vs Real Dog 🐕‍🦺#shorts   3787416
# 2  cDC-aloZLuk                iPhone 17 Pro Water Test Till DEAD😵  14094281
# 3  PNWqGdb-Vic  नेता जी को मिला कमाल के Features वाला Phone vi...   1484665
# 4  oKYQqvkj-cM                    Titanic Raise Reality 🤯 #shorts   1838683
#
#     likes  comments          publish_date
# 0   36340       364  2026-01-17T09:04:21Z
# 1  101512       436  2026-01-16T09:54:35Z
# 2  700215      5355  2026-01-14T08:15:11Z
# 3   64852       462  2026-01-13T12:31:20Z
# 4   96770       671  2026-01-11T13:11:43Z

# %%
print("Number of rows (videos):", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows (videos): 65
# Number of columns: 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   video_id      65 non-null     object
#  1   title         65 non-null     object
#  2   views         65 non-null     int64
#  3   likes         65 non-null     int64
#  4   comments      65 non-null     int64
#  5   publish_date  65 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 3.2+ KB

# %%
df.describe()
# Out:
#               views         likes      comments
# count  6.500000e+01  6.500000e+01     65.000000
# mean   1.319219e+07  5.037725e+05   2684.384615
# std    1.876444e+07  5.106086e+05   7268.282099
# min    7.530070e+05  3.634000e+04    129.000000
# 25%    3.055735e+06  1.453700e+05    444.000000
# 50%    5.867807e+06  3.627150e+05    691.000000
# 75%    1.531734e+07  6.808740e+05   1562.000000
# max    1.162838e+08  2.219897e+06  41884.000000

# %%
df.isnull().sum()
# Out:
# video_id        0
# title           0
# views           0
# likes           0
# comments        0
# publish_date    0
# dtype: int64

# %%
df["title"].nunique()
# Out:
# 65

# %%
OUTPUT_PATH = "../data/processed/verified_raw_social_data.csv"
df.to_csv(OUTPUT_PATH, index=False)

print("Verified raw data saved successfully!")
# Out:
# Verified raw data saved successfully!

# %%
## Conclusion

'''In this module, an automated data extraction pipeline was implemented
using the YouTube Data API. The collected dataset contains real-world
content performance metrics and is validated for further analytical
processing in upcoming modules.'''
# Out:
# 'In this module, an automated data extraction pipeline was implemented\nusing the YouTube Data API. The collected dataset contains real-world\ncontent performance metrics and is validated for further analytical\nprocessing in upcoming modules.'
